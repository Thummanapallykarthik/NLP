# %% [markdown]
# <a href="https://colab.research.google.com/github/Thummanapallykarthik/NLP/blob/main/nlp_lab_03_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TASK #2**

# %%
SRUniversity="""The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana, India.
It is in 150 acres, with both separate hostel facilities for boys and girls.
There is a huge central library along with Indias largest Technology Business Incubator (TBI) in tier 2 cities."""

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
SRUniversity="""The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana, India.
It is in 150 acres, with both separate hostel facilities for boys and girls.
There is a huge central library along with Indias largest Technology Business Incubator (TBI) in tier 2 cities."""
tokens = nltk.word_tokenize(SRUniversity)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [('The', 'DT'), ('SR', 'NNP'), ('University', 'NNP'), ('campus', 'NN'), ('is', 'VBZ'), ('located', 'VBN'), ('in', 'IN'), ('Ananthasagar', 'NNP'), ('village', 'NN'), ('of', 'IN'), ('Hasanparthy', 'NNP'), ('Mandal', 'NNP'), ('in', 'IN'), ('Warangal', 'NNP'), (',', ','), ('Telangana', 'NNP'), (',', ','), ('India', 'NNP'), ('.', '.'), ('It', 'PRP'), ('is', 'VBZ'), ('in', 'IN'), ('150', 'CD'), ('acres', 'NNS'), (',', ','), ('with', 'IN'), ('both', 'DT'), ('separate', 'JJ'), ('hostel', 'NN'), ('facilities', 'NNS'), ('for', 'IN'), ('boys', 'NNS'), ('and', 'CC'), ('girls', 'NNS'), ('.', '.'), ('There', 'EX'), ('is', 'VBZ'), ('a', 'DT'), ('huge', 'JJ'), ('central', 'JJ'), ('library', 'NN'), ('along', 'IN'), ('with', 'IN'), ('Indias', 'NNP'), ('largest', 'JJS'), ('Technology', 'NN'), ('Business', 'NNP'), ('Incubator', 'NNP'), ('(', '('), ('TBI', 'NNP'), (')', ')'), ('in', 'IN'), ('tier', '$'), ('2', 'CD'), ('cities', 'NNS'), ('.', '.')]
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(SRUniversity)
for token in doc:
  print(token.text, token.pos_)
# Out:
# The DET
# SR PROPN
# University PROPN
# campus NOUN
# is AUX
# located VERB
# in ADP
# Ananthasagar PROPN
# village NOUN
# of ADP
# Hasanparthy PROPN
# Mandal PROPN
# in ADP
# Warangal PROPN
# , PUNCT
# Telangana PROPN
# , PUNCT
# India PROPN
# . PUNCT
#
#  SPACE
# It PRON
# is AUX
# in ADP
# 150 NUM
# acres NOUN
# , PUNCT
# with ADP
# both DET
# separate ADJ
# hostel NOUN
# facilities NOUN
# for ADP
# boys NOUN
# and CCONJ
# girls NOUN
# . PUNCT
#
#  SPACE
# There PRON
# is VERB
# a DET
# huge ADJ
# central ADJ
# library NOUN
# along ADP
# with ADP
# Indias PROPN
# largest ADJ
# Technology PROPN
# Business PROPN
# Incubator PROPN
# ( PUNCT
# TBI PROPN
# ) PUNCT
# in ADP
# tier NOUN
# 2 NUM
# cities NOUN
# . PUNCT

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(SRUniversity)
for token in doc:
 print(token.text, token.pos_, token.tag_)
# Out:
# The DET DT
# SR PROPN NNP
# University PROPN NNP
# campus NOUN NN
# is AUX VBZ
# located VERB VBN
# in ADP IN
# Ananthasagar PROPN NNP
# village NOUN NN
# of ADP IN
# Hasanparthy PROPN NNP
# Mandal PROPN NNP
# in ADP IN
# Warangal PROPN NNP
# , PUNCT ,
# Telangana PROPN NNP
# , PUNCT ,
# India PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# It PRON PRP
# is AUX VBZ
# in ADP IN
# 150 NUM CD
# acres NOUN NNS
# , PUNCT ,
# with ADP IN
# both DET DT
# separate ADJ JJ
# hostel NOUN NN
# facilities NOUN NNS
# for ADP IN
# boys NOUN NNS
# and CCONJ CC
# girls NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# There PRON EX
# is VERB VBZ
# a DET DT
# huge ADJ JJ
# central ADJ JJ
# library NOUN NN
# along ADP IN
# with ADP IN
# Indias PROPN NNP
# largest ADJ JJS
# Technology PROPN NNP
# Business PROPN NNP
# Incubator PROPN NNP
# ( PUNCT -LRB-
# TBI PROPN NNP
# ) PUNCT -RRB-
# in ADP IN
# tier NOUN NN
# 2 NUM CD
# cities NOUN NNS
# . PUNCT .

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
SRUniversity="""The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana, India.
It is in 150 acres, with both separate hostel facilities for boys and girls.
There is a huge central library along with Indias largest Technology Business Incubator (TBI) in tier 2 cities."""

doc = nlp(SRUniversity)
nouns = []
verbs = []
for token in doc:
 if token.pos_ in ["NOUN", "PROPN"]:
  nouns.append(token.text)
 elif token.pos_ == "VERB":
  verbs.append(token.text)
  noun_freq = Counter(nouns)
  verb_freq = Counter(verbs)
  print("Noun Frequency:", noun_freq)
  print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'SR': 1, 'University': 1, 'campus': 1})
# Verb Frequency: Counter({'located': 1})
# Noun Frequency: Counter({'SR': 1, 'University': 1, 'campus': 1, 'Ananthasagar': 1, 'village': 1, 'Hasanparthy': 1, 'Mandal': 1, 'Warangal': 1, 'Telangana': 1, 'India': 1, 'acres': 1, 'hostel': 1, 'facilities': 1, 'boys': 1, 'girls': 1})
# Verb Frequency: Counter({'located': 1, 'is': 1})

# %% [markdown]
# # **TASK #1**

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')
sentence = "Students are learning Natural Language Processing"
tokens = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [('Students', 'NNS'), ('are', 'VBP'), ('learning', 'VBG'), ('Natural', 'NNP'), ('Language', 'NNP'), ('Processing', 'NNP')]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Students are learning Natural Language Processing")
for token in doc:
 print(token.text, token.pos_)
# Out:
# Students NOUN
# are AUX
# learning VERB
# Natural PROPN
# Language PROPN
# Processing NOUN

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying a startup in India.")
for token in doc:
 print(token.text, token.pos_, token.tag_)
# Out:
# Apple PROPN NNP
# is AUX VBZ
# looking VERB VBG
# at ADP IN
# buying VERB VBG
# a DET DT
# startup NOUN NN
# in ADP IN
# India PROPN NNP
# . PUNCT .

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
text = "Loving the new AI features "
doc = nlp(text)
nouns = []
verbs = []
for token in doc:
 if token.pos_ in ["NOUN", "PROPN"]:
  nouns.append(token.text)
 elif token.pos_ == "VERB":
  verbs.append(token.text)
noun_freq = Counter(nouns)
verb_freq = Counter(verbs)
print("Noun Frequency:", noun_freq)
print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'AI': 1})
# Verb Frequency: Counter({'Loving': 1, 'features': 1})

# %% [markdown]
# ### ***task##3***

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')
sentence =  "Morning light spills through the window, turning ordinary moments into something quietly remarkable. Coffee cools on the desk while notifications wait, ignored, as thoughts wander toward plans, doubts, and small hopes. Productivity feels less like force and more like rhythm, a balance between focus and rest. Outside, traffic hums, trees sway, and life continues without urgency. Inside, a decision forms to begin anyway, imperfectly, trusting progress over perfection. Each sentence written, each task started, builds momentum. The day doesn’t promise miracles, but it offers chances, and that feels like enough. Today invites patience, curiosity, courage, kindness, resilience, attention, humility, gratitude."
tokens = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [('Morning', 'VBG'), ('light', 'NN'), ('spills', 'NNS'), ('through', 'IN'), ('the', 'DT'), ('window', 'NN'), (',', ','), ('turning', 'VBG'), ('ordinary', 'JJ'), ('moments', 'NNS'), ('into', 'IN'), ('something', 'NN'), ('quietly', 'RB'), ('remarkable', 'JJ'), ('.', '.'), ('Coffee', 'NNP'), ('cools', 'VBZ'), ('on', 'IN'), ('the', 'DT'), ('desk', 'NN'), ('while', 'IN'), ('notifications', 'NNS'), ('wait', 'VBP'), (',', ','), ('ignored', 'VBN'), (',', ','), ('as', 'IN'), ('thoughts', 'NNS'), ('wander', 'VBP'), ('toward', 'IN'), ('plans', 'NNS'), (',', ','), ('doubts', 'NNS'), (',', ','), ('and', 'CC'), ('small', 'JJ'), ('hopes', 'NNS'), ('.', '.'), ('Productivity', 'NNP'), ('feels', 'VBZ'), ('less', 'RBR'), ('like', 'IN'), ('force', 'NN'), ('and', 'CC'), ('more', 'JJR'), ('like', 'IN'), ('rhythm', 'NN'), (',', ','), ('a', 'DT'), ('balance', 'NN'), ('between', 'IN'), ('focus', 'NN'), ('and', 'CC'), ('rest', 'NN'), ('.', '.'), ('Outside', 'NNP'), (',', ','), ('traffic', 'NN'), ('hums', 'NNS
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp( "Morning light spills through the window, turning ordinary moments into something quietly remarkable. Coffee cools on the desk while notifications wait, ignored, as thoughts wander toward plans, doubts, and small hopes. Productivity feels less like force and more like rhythm, a balance between focus and rest. Outside, traffic hums, trees sway, and life continues without urgency. Inside, a decision forms to begin anyway, imperfectly, trusting progress over perfection. Each sentence written, each task started, builds momentum. The day doesn’t promise miracles, but it offers chances, and that feels like enough. Today invites patience, curiosity, courage, kindness, resilience, attention, humility, gratitude.")
for token in doc:
 print(token.text, token.pos_)
# Out:
# Morning PROPN
# light NOUN
# spills VERB
# through ADP
# the DET
# window NOUN
# , PUNCT
# turning VERB
# ordinary ADJ
# moments NOUN
# into ADP
# something PRON
# quietly ADV
# remarkable ADJ
# . PUNCT
# Coffee NOUN
# cools VERB
# on ADP
# the DET
# desk NOUN
# while SCONJ
# notifications NOUN
# wait VERB
# , PUNCT
# ignored VERB
# , PUNCT
# as SCONJ
# thoughts NOUN
# wander VERB
# toward ADP
# plans NOUN
# , PUNCT
# doubts NOUN
# , PUNCT
# and CCONJ
# small ADJ
# hopes NOUN
# . PUNCT
# Productivity PROPN
# feels VERB
# less ADV
# like ADP
# force NOUN
# and CCONJ
# more ADJ
# like ADP
# rhythm NOUN
# , PUNCT
# a DET
# balance NOUN
# between ADP
# focus NOUN
# and CCONJ
# rest NOUN
# . PUNCT
# Outside ADV
# , PUNCT
# traffic NOUN
# hums NOUN
# , PUNCT
# trees NOUN
# sway VERB
# , PUNCT
# and CCONJ
# life NOUN
# continues VERB
# without ADP
# urgency NOUN
# . PUNCT
# Inside ADV
# , PUNCT
# a DET
# decision NOUN
# forms NOUN
# to PART
# begin VERB
# anyway ADV
# , PUNCT
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(" Morning light spills through the window, turning ordinary moments into something quietly remarkable. Coffee cools on the desk while notifications wait, ignored, as thoughts wander toward plans, doubts, and small hopes. Productivity feels less like force and more like rhythm, a balance between focus and rest. Outside, traffic hums, trees sway, and life continues without urgency. Inside, a decision forms to begin anyway, imperfectly, trusting progress over perfection. Each sentence written, each task started, builds momentum. The day doesn’t promise miracles, but it offers chances, and that feels like enough. Today invites patience, curiosity, courage, kindness, resilience, attention, humility, gratitude. .")
for token in doc:
 print(token.text, token.pos_, token.tag_)
# Out:
#   SPACE _SP
# Morning PROPN NNP
# light NOUN NN
# spills VERB VBZ
# through ADP IN
# the DET DT
# window NOUN NN
# , PUNCT ,
# turning VERB VBG
# ordinary ADJ JJ
# moments NOUN NNS
# into ADP IN
# something PRON NN
# quietly ADV RB
# remarkable ADJ JJ
# . PUNCT .
# Coffee NOUN NN
# cools VERB VBZ
# on ADP IN
# the DET DT
# desk NOUN NN
# while SCONJ IN
# notifications NOUN NNS
# wait VERB VBP
# , PUNCT ,
# ignored VERB VBN
# , PUNCT ,
# as SCONJ IN
# thoughts NOUN NNS
# wander VERB VBP
# toward ADP IN
# plans NOUN NNS
# , PUNCT ,
# doubts NOUN NNS
# , PUNCT ,
# and CCONJ CC
# small ADJ JJ
# hopes NOUN NNS
# . PUNCT .
# Productivity PROPN NNP
# feels VERB VBZ
# less ADV RBR
# like ADP IN
# force NOUN NN
# and CCONJ CC
# more ADJ JJR
# like ADP IN
# rhythm NOUN NN
# , PUNCT ,
# a DET DT
# balance NOUN NN
# between ADP IN
# focus NOUN NN
# and CCONJ CC
# rest NOUN NN
# . PUNCT .
# Outside ADV RB
# , PUNCT ,
# traffic NOUN NN
# hums NOUN NNS
# , PUNCT ,
# trees NOUN NNS
# sway VERB VBP
# ...

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
text = "Morning light spills through the window, turning ordinary moments into something quietly remarkable. Coffee cools on the desk while notifications wait, ignored, as thoughts wander toward plans, doubts, and small hopes. Productivity feels less like force and more like rhythm, a balance between focus and rest. Outside, traffic hums, trees sway, and life continues without urgency. Inside, a decision forms to begin anyway, imperfectly, trusting progress over perfection. Each sentence written, each task started, builds momentum. The day doesn’t promise miracles, but it offers chances, and that feels like enough. Today invites patience, curiosity, courage, kindness, resilience, attention, humility, gratitude."

doc = nlp(text)
nouns = []
verbs = []
for token in doc:
 if token.pos_ in ["NOUN", "PROPN"]:
  nouns.append(token.text)
 elif token.pos_ == "VERB":
  verbs.append(token.text)
noun_freq = Counter(nouns)
verb_freq = Counter(verbs)
print("Noun Frequency:", noun_freq)
print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'Morning': 1, 'light': 1, 'window': 1, 'moments': 1, 'Coffee': 1, 'desk': 1, 'notifications': 1, 'thoughts': 1, 'plans': 1, 'doubts': 1, 'hopes': 1, 'Productivity': 1, 'force': 1, 'rhythm': 1, 'balance': 1, 'focus': 1, 'rest': 1, 'traffic': 1, 'hums': 1, 'trees': 1, 'life': 1, 'urgency': 1, 'decision': 1, 'forms': 1, 'progress': 1, 'perfection': 1, 'sentence': 1, 'task': 1, 'momentum': 1, 'day': 1, 'miracles': 1, 'chances': 1, 'Today': 1, 'patience': 1, 'curiosity': 1, 'courage': 1, 'kindness': 1, 'resilience': 1, 'attention': 1, 'humility': 1, 'gratitude': 1})
# Verb Frequency: Counter({'feels': 2, 'spills': 1, 'turning': 1, 'cools': 1, 'wait': 1, 'ignored': 1, 'wander': 1, 'sway': 1, 'continues': 1, 'begin': 1, 'trusting': 1, 'written': 1, 'started': 1, 'builds': 1, 'promise': 1, 'offers': 1, 'invites': 1})
